# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('job_descriptions.csv')

# %%
df.head(2)
# Out:
#              Job Id     Experience Qualifications Salary Range  location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K   Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K  Ashgabat
#
#         Country  latitude  longitude Work Type  Company Size  ...  \
# 0   Isle of Man   54.2361    -4.5481    Intern         26801  ...
# 1  Turkmenistan   38.9697    59.5563    Intern        100340  ...
#
#                 Contact                     Job Title                    Role  \
# 0  001-381-930-7517x737  Digital Marketing Specialist    Social Media Manager
# 1          461-509-4216                 Web Developer  Frontend Web Developer
#
#   Job Portal                                    Job Description  \
# 0   Snagajob  Social Media Managers oversee an organizations...
# 1   Idealist  Frontend Web Developers design and implement u...
#
#                                             Benefits  \
# 0  {'Flexible Spending Accounts (FSAs), Relocatio...
# ...

# %%
df.rename(columns={'Job Id': 'Job_Id','Salary Range':'Salary_Range','Work Type': 'Work_type','Company Size': 'Company_Size','Job Posting Date': 'Job_Posting_Date','Contact Person': 'Contact_Person','Job Title': 'Job_title','Job Portal': 'Job_Portal','Job Description': 'Job_description','Company Profile':'Company_Profile'},inplace=True)

# %%
df.Job_title
# Out:
# 0          Digital Marketing Specialist
# 1                         Web Developer
# 2                    Operations Manager
# 3                      Network Engineer
# 4                         Event Manager
#                        ...
# 1615935             Mechanical Engineer
# 1615936                      IT Manager
# 1615937             Mechanical Engineer
# 1615938                  HR Coordinator
# 1615939                   Event Planner
# Name: Job_title, Length: 1615940, dtype: object

# %%
df.isnull().sum()
# Out:
# Job_Id                 0
# Experience             0
# Qualifications         0
# Salary_Range           0
# location               0
# Country                0
# latitude               0
# longitude              0
# Work_type              0
# Company_Size           0
# Job_Posting_Date       0
# Preference             0
# Contact_Person         0
# Contact                0
# Job_title              0
# Role                   0
# Job_Portal             0
# Job_description        0
# Benefits               0
# skills                 0
# Responsibilities       0
# Company                0
# Company_Profile     5478
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Job_Id              0
# Experience          0
# Qualifications      0
# Salary_Range        0
# location            0
# Country             0
# latitude            0
# longitude           0
# Work_type           0
# Company_Size        0
# Job_Posting_Date    0
# Preference          0
# Contact_Person      0
# Contact             0
# Job_title           0
# Role                0
# Job_Portal          0
# Job_description     0
# Benefits            0
# skills              0
# Responsibilities    0
# Company             0
# Company_Profile     0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.Role
# Out:
# 0                Social Media Manager
# 1              Frontend Web Developer
# 2             Quality Control Manager
# 3           Wireless Network Engineer
# 4                  Conference Manager
#                       ...
# 1615935    Mechanical Design Engineer
# 1615936                   IT Director
# 1615937    Mechanical Design Engineer
# 1615938          Training Coordinator
# 1615939               Wedding Planner
# Name: Role, Length: 1610462, dtype: object

# %%
task1_jobtitle=df[df['Job_title']=='UX/UI Designer']

# %%
task1_role=df[df['Role']=='User Experience Designer']

# %%
df[df['Role']=='User Experience Designer']
# Out:
#                    Job_Id     Experience Qualifications Salary_Range  \
# 377       593675884325624   1 to 8 Years          M.Com    $65K-$83K
# 405       723171043133877  5 to 13 Years          B.Com   $60K-$130K
# 466      1524163597812972  1 to 11 Years             BA    $62K-$90K
# 657       243219404665372  1 to 11 Years            BCA   $60K-$100K
# 705        78558602635986  1 to 15 Years          M.Com    $64K-$98K
# ...                   ...            ...            ...          ...
# 1615174  1241152255426384  3 to 15 Years            PhD    $58K-$89K
# 1615224  2510864842012039  3 to 14 Years            MCA   $58K-$104K
# 1615376   801615373584794  5 to 14 Years         B.Tech   $56K-$127K
# 1615627  2599628045133607  1 to 13 Years            MBA    $63K-$80K
# 1615732  3052268302297084  4 to 14 Years            PhD   $63K-$115K
#
#                location                 Country  latitude  longitude  \
# ...

# %%
task1_jobtitle
# Out:
#                    Job_Id     Experience Qualifications Salary_Range  \
# 7        1498778686197107   2 to 8 Years          M.Com   $65K-$102K
# 8        1680293940995740   2 to 9 Years            BBA   $65K-$102K
# 37        487916817418719   0 to 8 Years             BA   $64K-$103K
# 72       1541299387735451  5 to 14 Years             BA   $56K-$128K
# 82        448038582846953  4 to 13 Years            MCA    $65K-$96K
# ...                   ...            ...            ...          ...
# 1615823  2155671934161466  4 to 15 Years            BCA    $60K-$93K
# 1615842   220799448097206  0 to 13 Years             BA    $64K-$84K
# 1615900   203600931048070  3 to 13 Years             BA   $58K-$104K
# 1615904   296584591590057  0 to 15 Years          M.Com   $59K-$121K
# 1615928  1827059374762454  5 to 12 Years          B.Com   $58K-$115K
#
#            location                         Country  latitude  longitude  \
# ...

# %%
filtered_df = df[(df['Job_title']=='UX/UI Designer') & (df['Role']=='User Experience Designer') & (df['Company'].apply(len)>5)]

# %%
filtered_df
# Out:
#                    Job_Id     Experience Qualifications Salary_Range  \
# 377       593675884325624   1 to 8 Years          M.Com    $65K-$83K
# 466      1524163597812972  1 to 11 Years             BA    $62K-$90K
# 657       243219404665372  1 to 11 Years            BCA   $60K-$100K
# 705        78558602635986  1 to 15 Years          M.Com    $64K-$98K
# 886      2378990584323118   0 to 8 Years            BCA   $56K-$126K
# ...                   ...            ...            ...          ...
# 1615083  2039213157603955  0 to 12 Years          B.Com   $62K-$110K
# 1615174  1241152255426384  3 to 15 Years            PhD    $58K-$89K
# 1615376   801615373584794  5 to 14 Years         B.Tech   $56K-$127K
# 1615627  2599628045133607  1 to 13 Years            MBA    $63K-$80K
# 1615732  3052268302297084  4 to 14 Years            PhD   $63K-$115K
#
#                location                 Country  latitude  longitude  \
# ...

# %%
filtered_df.to_csv('output_dataset.csv', index=False)

# %%
filtered_df['Company'].value_counts().head(20)
# Out:
# Company
# Chipotle Mexican Grill    28
# Viatris                   28
# Vonovia SE                28
# Micron Technology         28
# Cummins                   27
# Diageo                    27
# AutoNation                27
# Munich Re Group           25
# Humana                    25
# Seven Group Holdings      25
# Page Industries           25
# Ross Stores               25
# Bajaj Finance             25
# Great Wall Motors         25
# Fifth Third Bancorp       25
# Deutsche Bahn AG          25
# Stanley Black & Decker    24
# Corning                   24
# Coty Inc.                 24
# Victrex                   24
# Name: count, dtype: int64
